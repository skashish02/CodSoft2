# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\CodSoft Tasks\Task2-Sales\advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(data, x_vars=['TV', 'Radio','Newspaper'], y_vars='Sales', kind='scatter')
plt.show()

# %%
data['TV'].plot.hist(bins=10, color="blue", xlabel="TV")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Radio'].plot.hist(bins=10, color="red", xlabel="Radio")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Newspaper'].plot.hist(bins=10, color="green", xlabel="Newspaper")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.heatmap(data.corr(),annot = True)
plt.show()

# %%
#TV has the high correlation with sales

# %%
#Training the model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['TV']], data[['Sales']], test_size = 0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
res= model.predict(X_test)
print(res)
# Out:
# [[10.93127621]
#  [ 9.88042193]
#  [12.09159447]
#  [22.99968079]
#  [16.45920756]
#  [10.21976029]
#  [ 7.6199906 ]
#  [20.28497391]
#  [ 8.4464437 ]
#  [17.95886418]
#  [21.44529217]
#  [11.91645209]
#  [15.71485245]
#  [17.42249065]
#  [11.32534656]
#  [13.72260788]
#  [21.68063975]
#  [ 7.18213465]
#  [11.23230217]
#  [18.82362968]
#  [22.88474361]
#  [14.82272095]
#  [16.72739433]
#  [14.35202581]
#  [10.07198391]
#  [13.88133066]
#  [16.20744039]
#  [18.36388094]
#  [19.40378881]
#  [ 8.51759529]
#  [10.85465142]
#  [18.03001578]
#  [22.50709285]
#  [20.3725451 ]
#  [ 7.86628457]
#  [ 8.16731053]
#  [10.40584907]
#  [17.03936669]
#  [10.88749061]
#  [ 8.51212209]
#  [ 9.16343282]
#  [ 8.86788005]
#  [14.96502414]
#  [18.61564811]
#  [18.93309367]
#  [12.76479799]
#  [ 7.6145174 ]
#  [ 8.06879294]
#  [14.02363385]
#  [12.86878878]
#  [13.15339515]
#  [19.70481478]
#  [21.03480222]
#  [17.26376787]
#  [ 9.59034237]
#  [10.55362545]
#  [23.17482317]
#  [16.58509115]
# ...

# %%
accuracy_linear = model.score(X_test, y_test)
print(f'Accuracy: {accuracy_linear * 100:.2f}%')
# Out:
# Accuracy: 81.50%

# %%
plt.style.use('default')
plt.grid()
plt.scatter(X_test, y_test)
plt.plot(X_test, 7.14382225 + 0.05473199 * X_test, 'r')
plt.show()
